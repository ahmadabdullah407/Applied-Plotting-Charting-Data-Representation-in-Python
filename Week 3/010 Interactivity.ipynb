# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import pandas as pd

# %% [markdown]
# # Interactivity:
# Intercativity is very much alike animation but in this case instead of iteration function needs an event(like mose click, key press etc.) to execute.
# ## button_press_event:

# %%
plt.figure()
data = np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {},{} \nand data {},{}'.format(event.x, event.y, event.xdata, event.ydata))

# tell mpl_connect we want to pass a 'button_press_event' into onclick when the event is detected
plt.gcf().canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# 9

# %% [markdown]
# ## pick_event:

# %%
from random import shuffle
origins = ['China', 'Brazil', 'India', 'USA', 'Canada', 'UK', 'Germany', 'Iraq', 'Chile', 'Mexico']

shuffle(origins)

df = pd.DataFrame({'height': np.random.rand(10),
                   'weight': np.random.rand(10),
                   'origin': origins})
df
# Out:
#      height    weight   origin
# 0  0.450084  0.156761    China
# 1  0.759198  0.250131      USA
# 2  0.940893  0.861372  Germany
# 3  0.642915  0.696404   Brazil
# 4  0.162417  0.014162    India
# 5  0.815853  0.054669     Iraq
# 6  0.756404  0.805367   Canada
# 7  0.010213  0.175904    Chile
# 8  0.540515  0.843995   Mexico
# 9  0.874322  0.783759       UK

# %%
plt.figure()
# picker=5 means the mouse doesn't have to click directly on an event, but can be up to 5 pixels away
plt.scatter(df['height'], df['weight'], picker=5)
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# Text(0.5, 0, 'Height')

# %%
def onpick(event):
    # event.ind[0] provides the index for the data check below codeblock to clear concepts
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Selected item came from {}'.format(origin))

# tell mpl_connect we want to pass a 'pick_event' into onpick when the event is detected
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 10

# %%
df.iloc[5]
# Out:
# height     0.815853
# weight    0.0546688
# origin         Iraq
# Name: 5, dtype: object
