# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import pandas as pd

# %% [markdown]
# # Heatmaps:
# Heatmaps are basically two dimensional histograms.
#
# In Heatmaps you have two dimensions latitude and longitude and the we can overlay on top of it a 3rd dimnsion say temperature or a rain etc. and use color to indicate its intensity.

# %%
plt.figure()

Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
_ = plt.hist2d(X, Y, bins=25)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %%
plt.figure()
_ = plt.hist2d(X, Y, bins=100)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %%
plt.figure()
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.normal(loc=0.0, scale=1.0, size=10000)
_ = plt.hist2d(X, Y, bins=25)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# add a colorbar legend

# %%
plt.colorbar()
