# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
plt.subplot?

# %% [markdown]
# # subplots:

# %% [markdown]
# ## subplot with 1 row, 2 columns, and current axis is 1st subplot axes:

# %%
def plot1():
    plt.figure()
    plt.subplot(1,2,1)
    linear_data = np.array([1,2,3,4,5,6,7,8])
    plt.plot(linear_data, '-o')
plot1()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ## subplot with 1 row, 2 columns, and current axis is 2nd subplot axes:

# %%
plot1()
def plot2():
    exponential_data=linear_data**2
    plt.subplot(1,2,2)
    plt.plot(exponential_data,'-o')
plot2()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ## plot exponential data on 1st subplot axes:

# %%
plot1()
plot2()
def plot3():
    plt.subplot(1,2,1)
    plt.plot(exponential_data,'-x')
plot3()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <ipython-input-19-b82324e96f8a>:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(1,2,1)

# %% [markdown]
# ## pass sharey=ax1 to ensure the two subplots share the same y axis:

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot(linear_data,'-o')
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot(exponential_data,'-x')
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ## the right hand side is equivalent shorthand syntax:

# %%
plt.figure()
# the right hand side is equivalent shorthand syntax
plt.subplot(1,2,1) == plt.subplot(121)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <ipython-input-22-2c808a67d888>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(1,2,1) == plt.subplot(121)
# True

# %% [markdown]
# ## subplots():
# lets create a 3x3 grid of subplots, and plot the linear_data on the 5th subplot axes.

# %%
def subplots1():
    fig, ((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,
                                                                 sharex=True,
                                                                 sharey=True)
    ax5.plot(linear_data,'-')
subplots1()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ## set inside tick labels to visible(lecture method is given below but it was not working for me):

# %%
subplots1()
for ax in plt.gcf().get_axes():
    ax.yaxis.set_tick_params(labelleft=True)
    ax.xaxis.set_tick_params(labelbottom=True)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ## set inside tick labels to visible (lecture method):

# %%
subplots1()
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)
# necessary on some systems to update the plot
plt.gcf().canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
