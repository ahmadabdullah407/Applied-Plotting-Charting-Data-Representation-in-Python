# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import pandas as pd

# %% [markdown]
# # Animations:

# %% [markdown]
# ## FuncAnimation():
# It is a function that calls some other function we define iteratively to build an animation.
#
# Now 1st lets create a numpy array of normal distribution with size 100. np.random.randn creates a normal distribution array of size specified with mean 0 and variance 1.

# %%
import matplotlib.animation as animation
n = 100
x = np.random.randn(n)
x
# Out:
# array([ 0.46028748, -1.5307829 , -0.18629733,  0.92077174, -0.33294257,
#         1.43729622, -1.14260622,  0.49840832, -0.76569779,  0.80896243,
#        -0.72071742,  1.183312  , -0.08166343, -1.96663278,  1.24194784,
#         2.02126366,  0.94803849, -0.17548219,  0.87071384,  0.55767602,
#        -0.09664308, -0.97214282, -0.06067071, -1.85416454,  0.1286678 ,
#         1.47315461, -0.75399853, -0.04648636,  1.1651445 , -1.28419256,
#         0.22842784,  0.49576729,  2.68878408, -1.37743066,  0.01621849,
#         1.27446311,  1.17927161, -0.09370506, -0.40397389,  0.39897542,
#         0.43890142, -0.23671974, -0.87406847,  0.53695231, -0.47386486,
#        -0.14747581,  1.10029278,  1.77395676,  1.63809983, -1.92959418,
#         1.10190276, -0.93299868,  0.30182356, -0.33913276,  1.08173749,
#        -0.8316401 ,  0.09055963,  0.78380745, -0.07752513,  0.55678632,
#        -0.33848066,  0.64471605,  0.87474173,  0.79160686, -1.49411018,
# ...

# %% [markdown]
# Now lets define a function which should be passed within FuncAnimation function to create an animation.

# %%
def update(curr):# curr is the index the function is at in array
    # check if animation is at the last frame, and if so, stop the animation a
    if curr == n: 
        a.event_source.stop()
    # clear the axis
    plt.cla()
    # We can also passin the spacing between bins as np array
    bins = np.arange(-4, 4, 0.5)
    # Create histogram till curr index
    plt.hist(x[:curr], bins=bins)
    # we need to set axis each time bcz histogram will try to autoscale
    plt.axis([-4,4,0,30])
    # labeling
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
#     annotate places a text at specified position in the chart,
# we'll use it to show how many samples are currently being rendered to the screen
    plt.annotate('n = {}'.format(curr), [3,27])

# %% [markdown]
# in animation.FuncAnimation() we pass in figure, function and interval that is time interval between function execution in this case it is 100ms.

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# The animation object has a handy safe function which allows you to write animation to a file. This requires an additional 3rd party library such as FFM page which can take a bit to install and setup. But the result is that you can fairly easily export your animations directly from jupyter web programming environment.
